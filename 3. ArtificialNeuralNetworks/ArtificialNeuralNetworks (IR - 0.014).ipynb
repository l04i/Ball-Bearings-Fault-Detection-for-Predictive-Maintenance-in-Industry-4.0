# %%
#importing packages
import pandas as pd
import numpy as np

# %%
# Importing the dataset
nb = pd.read_csv('../Dataset/NB.csv')
nb['Fault'] = 0

ir = pd.read_csv('../Dataset/IR014.csv')
ir['Fault'] = 1

# %%
dataset = nb.append(ir)
dataset
# Out:
# C:\Users\loaia\AppData\Local\Temp\ipykernel_10520\156461942.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = nb.append(ir)
#               DE        FE  Fault
# 0       0.046104  0.023216      0
# 1      -0.037134  0.081155      0
# 2      -0.089496  0.095331      0
# 3      -0.084906  0.091016      0
# 4      -0.038594  0.038625      0
# ...          ...       ...    ...
# 381885  0.262503 -0.084647      1
# 381886  0.325937 -0.087729      1
# 381887  0.361411 -0.054856      1
# 381888  0.361411 -0.030202      1
# 381889  0.345135 -0.010889      1
#
# [865793 rows x 3 columns]

# %%
X = dataset.iloc[:, 0:2].values
y = dataset.iloc[:, 2]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier_b = Sequential()

# %%
classifier_b.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 2))

# %%
classifier_b.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))

# %%
classifier_b.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
classifier_b.compile(optimizer = 'sgd', loss = 'binary_crossentropy', metrics = ['accuracy'])
classifier_b.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                192
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,305
# Trainable params: 2,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier_b.fit(X_train, y_train, batch_size = 32, epochs = 20, shuffle = False)
# Out:
# Epoch 1/20
# 21645/21645 [==============================] - 140s 6ms/step - loss: 0.6154 - accuracy: 0.6497
# Epoch 2/20
# 21645/21645 [==============================] - 136s 6ms/step - loss: 0.5565 - accuracy: 0.7112
# Epoch 3/20
# 21645/21645 [==============================] - 139s 6ms/step - loss: 0.5558 - accuracy: 0.7112
# Epoch 4/20
# 21645/21645 [==============================] - 137s 6ms/step - loss: 0.5556 - accuracy: 0.7114
# Epoch 5/20
# 21645/21645 [==============================] - 140s 6ms/step - loss: 0.5554 - accuracy: 0.7114
# Epoch 6/20
# 21645/21645 [==============================] - 139s 6ms/step - loss: 0.5554 - accuracy: 0.7115
# Epoch 7/20
# 21645/21645 [==============================] - 138s 6ms/step - loss: 0.5553 - accuracy: 0.7114
# Epoch 8/20
# 21645/21645 [==============================] - 137s 6ms/step - loss: 0.5553 - accuracy: 0.7114
# Epoch 9/20
# 21645/21645 [==============================] - 137s 6ms/step - loss: 0.5552 - accuracy: 0.7114
# Epoch 10/20
# 21645/21645 [==============================] - 137s 6ms/step - loss: 0.5552 - accuracy: 0.7114
# Epoch 11/20
# 21645/21645 [==============================] - 136s 6ms/step - loss: 0.5552 - accuracy: 0.7114
# Epoch 12/20
# 21645/21645 [==============================] - 138s 6ms/step - loss: 0.5552 - accuracy: 0.7114
# Epoch 13/20
# 21645/21645 [==============================] - 142s 7ms/step - loss: 0.5552 - accuracy: 0.7115
# Epoch 14/20
# 21645/21645 [==============================] - 141s 7ms/step - loss: 0.5551 - accuracy: 0.7115
# Epoch 15/20
# 21645/21645 [==============================] - 132s 6ms/step - loss: 0.5551 - accuracy: 0.7115
# Epoch 16/20
# 21645/21645 [==============================] - 134s 6ms/step - loss: 0.5551 - accuracy: 0.7115
# Epoch 17/20
# 21645/21645 [==============================] - 133s 6ms/step - loss: 0.5551 - accuracy: 0.7115
# Epoch 18/20
# 21645/21645 [==============================] - 132s 6ms/step - loss: 0.5551 - accuracy: 0.7115
# Epoch 19/20
# 21645/21645 [==============================] - 131s 6ms/step - loss: 0.5551 - accuracy: 0.7115
# Epoch 20/20
# 21645/21645 [==============================] - 128s 6ms/step - loss: 0.5551 - accuracy: 0.7115

# %%
y_pred = classifier_b.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 5412/5412 [==============================] - 29s 5ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

index = ['Normal', 'Inner Race (0.014")']  
columns = ['Normal', 'Inner Race (0.014")']  
cm_df = pd.DataFrame(cm,columns,index)  


plt.figure(figsize=(10,4))
sn.set(font_scale=1.4) # for label size
sn.heatmap(cm_df, annot=True, fmt='g') # font size
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

plt.show()

# %%
classifier_b.evaluate(X_test, y_test)
# Out:
# 5412/5412 [==============================] - 36s 6ms/step - loss: 0.5571 - accuracy: 0.7099
# [0.5571246147155762, 0.7099024653434753]

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred, target_names=['Normal', 'Inner Race (0.014")'])
print(cr)
# Out:
#                      precision    recall  f1-score   support
#
#              Normal       0.68      0.91      0.78     96849
# Inner Race (0.014")       0.80      0.45      0.58     76310
#
#            accuracy                           0.71    173159
#           macro avg       0.74      0.68      0.68    173159
#        weighted avg       0.73      0.71      0.69    173159

# %%
normal, IR = cm
anomalies = normal[1] + IR[0]
print("Anomalies: {}".format(anomalies))
# Out:
# Anomalies: 50233

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Obtain predicted probabilities for the positive class
y_prob = classifier_b.predict(X_test)

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
np.savez("roc_data_IR014.npz", fpr=fpr, tpr=tpr, thresholds=thresholds)
# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_score:.2f}', color='purple')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 5412/5412 [==============================] - 30s 5ms/step
